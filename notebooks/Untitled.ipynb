# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/07 05:17:36 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark.sql("SHOW TABLES IN novalake.gold").show(truncate=False)
# Out:
# +---------+-------------+-----------+
# |namespace|tableName    |isTemporary|
# +---------+-------------+-----------+
# |gold     |daily_revenue|false      |
# +---------+-------------+-----------+
